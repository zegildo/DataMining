# %% [markdown]
# # MT11
#
# Realize sua análise descritiva em cima dos dados apresentados pela UFERSA em: https://angicos.ufersa.edu.br/demonstrativo-de-despesas/
#
# 1. Elabore ao menos 5 perguntas relevantes
#
# 2. Responda suas perguntas com texto e gráficos
#
# 3. Chegue a alguma conclusão ou sugestão que ajudem os gestores a melhorarem sua atividade.
#
# 4. Toda atividade de ser gerada em um arquivo jupyter e submetida no github da disciplina, dentro da sua pasta pessoal, MT11.

# %% [markdown]
# ### import de bibliotecas

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
##matplotlib.style.use('ggplot')

# %% [markdown]
# ### Lendo os dados

# %%
Location = r'despesas.csv'
df = pd.read_csv(Location,sep=';')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 15 columns):
# mes                36 non-null object
# ano                36 non-null int64
# energia            35 non-null float64
# agua               35 non-null float64
# correios           35 non-null float64
# bolsas_auxilios    36 non-null int64
# limpeza            35 non-null float64
# portaria           11 non-null float64
# vigilancia         35 non-null float64
# agua_mineral       18 non-null float64
# motorista          35 non-null float64
# reprografia        26 non-null float64
# inscricoes         28 non-null float64
# aluno_evento       23 non-null float64
# dispensas          23 non-null float64
# dtypes: float64(12), int64(2), object(1)
# memory usage: 4.3+ KB

# %% [markdown]
# ### Descrição dos dados

# %%
df.describe()
# Out:
#                ano       energia         agua    correios  bolsas_auxilios  \
# count    36.000000     35.000000    35.000000   35.000000        36.000000
# mean   2016.000000  33107.503143  2969.593714   14.937429     68190.833333
# std       0.828079   8470.089992  1520.057872   31.083529     30683.241808
# min    2015.000000  18819.350000   588.240000    0.000000     10920.000000
# 25%    2015.000000  25453.320000  1700.215000    0.000000     42577.500000
# 50%    2016.000000  35378.720000  2916.120000    0.000000     75545.000000
# 75%    2017.000000  40465.860000  4119.020000   20.425000     92787.500000
# max    2017.000000  45046.060000  6663.980000  139.250000    105920.000000
#
#              limpeza      portaria    vigilancia  agua_mineral     motorista  \
# count      35.000000     11.000000     35.000000     18.000000     35.000000
# mean    39211.407429  15832.854545  29901.526000    579.926667  19286.455714
# ...

# %% [markdown]
# #### 1 - Qual a variação no consumo de energia por ano?

# %%
df.boxplot(column='energia', by='ano')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# #### 2 - Qual a variação nos valores gastos com bolsas e auxílios por ano?

# %%
df.boxplot(column='bolsas_auxilios', by='ano')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# #### 3 - Qual a evolução nos gastos com bolsas e auxílios nos útimos 3 anos?

# %%
df.plot.line(x='mes', y='bolsas_auxilios')
# Out:
# <img src="data:image/png;base64,..." width="950">

# %% [markdown]
# #### 4 -

# %% [markdown]
# #### 5 -
