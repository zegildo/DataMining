# %% [markdown]
# # Lei Rouanet

# %% [markdown]
# Principal mecanismo de fomento à Cultura do Brasil, a [Lei Rouanet](http://dados.gov.br/dataset/incentivos-da-lei-rouanet), como é conhecida a Lei 8.313/91, instituiu o Programa Nacional de Apoio à Cultura (Pronac). O nome Rouanet remete a seu criador, o então secretário Nacional de Cultura, o diplomata Sérgio Paulo Rouanet. Para cumprir este objetivo, a lei estabelece as normativas de como o Governo Federal deve disponibilizar recursos para a realização de projetos artístico-culturais. A Lei foi concebida originalmente com três mecanismos: o Fundo Nacional da Cultura (FNC), o Incentivo Fiscal e o Fundo de Investimento Cultural e Artístico (Ficart). Este nunca foi implementado, enquanto o Incentivo Fiscal - também chamado de mecenato - prevaleceu e chega ser confundido com a própria Lei.
#
# Mais informações sobre a Lei Rouanet podem ser obtidos em seu portal: http://rouanet.cultura.gov.br/

# %% [raw]
# # * 0) Obtenha os dados da [Lei Rouanet](http://dados.gov.br/dataset/incentivos-da-lei-rouanet) e organize-os em um banco de dados relacional ou diretamente na sua linguaguem de programação.
# * 1) Apresente os tipos de todas as variáveis e seus índices de tendência central quando for possível.
# * 2) Analise a poluição dos dados. Há dados nulos, vazios, problemáticos? Quantos? Quais? Como resolver? (Aproveite e resolva)
# * 3) Apresente ao menos uma forma de medir a similaridade entre projetos aprovados e outra para projetos não aprovados.
# * 4) Qual o projeto recebeu o maior investimento?
# * 5) Qual empresa investiu mais na Lei Rouanet ao longo do tempo?
# * 6) Qual foi a empresa mais beneficiada ao longo do tempo?
# * 7) Há algum solicitante que sempre ganha?
# * 8) Consegue associar algum CNPJ a algum artista conhecido?
# * 9) Apresente suas conclusões e hipóteses para o futuro baseado nos fatos encontrados.

# %% [markdown]
# # 1) Apresente os tipos de todas as variáveis e seus índices de tendência central quando for possível.
#  -----AREAS-----
#      codigo	 Nominal.
#      nome	 Nominal.
# -----FORNECEDORES-----
#  	 cgccpf	 Nominal.
#  	 email	 Nominal.
#  	 nome	 Nominal.
# -----INCENTIVADORES-----
#  	 nome	 Nominal.
#  	 cgccpf	 Nominal.
#  	 total_doado	 Racional.
#  	 tipo_pessoa	 Nominal.
#  	 responsavel	 Nominal.
#  	 UF	 Nominal.
#  	 Município	 Nominal.
# -----PROJETOS------
#  	 etapa	 Nominal.
#  	 providencia	 Nominal.
#  	 area	 Nominal.
#  	 enquadramento	 Nominal.
#  	 objetivos	 Nominal.
#  	 ficha_tecnica	 Nominal.
#  	 situacao	 Nominal.
#  	 outras_fontes	 Racional. - MEDIA = 553.01000
#  	 acessbilidade	 Nominal.
#  	 sinopse	 Nominal.
#  	 nome	 Nominal.
#  	 cgccpf	 Nominal.
#  	 mecanismo	 Nominal.
#  	 segmento	 Nominal.
#  	 PRONAC	 Nominal.
#  	 estrategia_execucao	 Nominal.
#  	 valor_aprovado	 Racional. - MEDIA - 0
#  	 justificativa	 Nominal.
#  	 resumo	 Nominal.
#  	 valorsolicitado	 Racional  - MEDIA = 1,246,866.004500
#  	 especificacao_tecnica	 Nominal.
#  	 municipio	 Nominal.
#  	 data_terminio	 Ordinal.
#  	 UF	 Nominal.
#  	 impacto_ambiental	 Nominal.
#  	 democratizacao	 Nominal.
#  	 valor_projeto	 Racional.
#  	 proponente	 Nominal.
#  	 ano_projeto	 Ordinal.
#  	 data_inicio	 Ordinal.
#  	 valor_captado	 Racional.
#  	 valor_proposta	 Racional.
#  -----PROPONETES-----
#  	 nome	 Nominal.
#  	 cgccpf	 Nominal.
#  	 tipo_pessoa	 Nominal.
#  	 responsavel	 Nominal.
#  	 UF	 Nominal.
#  	 total_captado	 Racional.
#  	 municipio	 Nominal.
# -----PROPOSTAS-----
#  	 data_arquivamento	 Ordinal.
#  	 acessibilidade	 Nominal.
#  	 impacto_ambiental	 Nominal.
#  	 nome	 Nominal.
#  	 democratizacao	 Nominal.
#  	 justificativa	 Nominal.
#  	 mecanismo	 Nominal.
#  	 resumo	 Nominal.
#  	 sinopse	 Nominal.
#  	 especificacao_tecnica	 Nominal.
#  	 data_inicio	 Ordinal.
#  	 objetivos	 Nominal.
#  	 ficha_tecnica	 Nominal.
#  	 etapa	 Nominal.
#  	 data_aceite	 Ordinal.
#  	 id	 Nominal.
#  	 estrategia_execucao	 Nominal.
#  	 data_termino	 Ordinal.
#  	 codigo	 Nominal.
#  	 nome	 Nominal.

# %% [markdown]
# # 2) Analise a poluição dos dados. Há dados nulos, vazios, problemáticos? Quantos? Quais? Como resolver? (Aproveite e resolva)
# TOTAL DE NULOS AREAS = 0
#
# SELECT COUNT(*) AS total_nulos FROM areas
# WHERE COLUNA is  null
#
#  codigo	0
#  nome	0
#
#
# TOTAL DE NULOS FORNECDORES = 49
#
# SELECT COUNT(*) AS total_nulos FROM fornecedores
# WHERE COLUNA is  null
#
# cgccpf - 0
# email - 49
# nome -0
#
#
# TOTAL DE NULOS INCENTIVADORES = 71
#
# SELECT COUNT(*) AS total_nulos FROM incentivadores
# WHERE COLUNA is  null
#
#  NOME - 0
#  cgccpf - 0
#  total_doado- 0
#  tipo_pessoa- 0
#  responsavel- 71
#  UF- 0
#  Município- 0
#
#  TOTAL DE NULOS PROJETOS = 137
#
#  SELECT COUNT(*) AS total_nulos FROM projtos
# WHERE COLUNA is  null
#
#  etapa	0
#  providencia	0
#  area	0
#  enquadramento	0
#  objetivos	0
#  ficha_tecnica	0
#  situacao	0
#  outras_fontes	0
#  acessbilidade	0
#  sinopse	4
#  nome 0
#  cgccpf	 0
#  mecanismo 0
#  segmento 0
#  PRONAC	 0
#  estrategia_execucao 30
#  valor_aprovado	0
#  justificativa	0
#  resumo	0
#  valorsolicitado	0
#  especificacao_tecnica	8
#  municipio	0
#  data_terminio	0
#  UF	0
#  impacto_ambiental	95
#  democratizacao	0
#  valor_projeto	0
#  proponente	0
#  ano_projeto	0
#  data_inicio	0
#  valor_captado	0
#  valor_proposta	0
#
#  TOTAL DE NULOS PROPONENTES = 7
#
#   SELECT COUNT(*) AS total_nulos FROM proponentes
# WHERE COLUNA is  null
#
#   nome	0
#  cgccpf	0
#  tipo_pessoa	0
#  responsavel	7
#  UF	0
#  total_captado	0
#  municipio	0
#
#   TOTAL DE NULOS PROPOSTAS = 635
#
#    SELECT COUNT(*) AS total_nulos FROM propostas
# WHERE COLUNA is  null
#
#    data_arquivamento	65
#  acessibilidade	1
#  impacto_ambiental	96
#  nome	0
#  democratizacao	4
#  justificativa	0
#  mecanismo	0
#  resumo	0
#  sinopse	96
#  especificacao_tecnica	96
#  data_inicio	0
#  objetivos	0
#  ficha_tecnica	95
#  etapa	4
#  data_aceite	100
#  id	0
#  estrategia_execucao	96
#  data_termino	0
#
#
#    TOTAL DE NULOS SEGMENTOS = 0
#
#    SELECT COUNT(*) AS total_nulos FROM segmentos
# WHERE COLUNA is  null
#
#  codigo	0
#  nome	0

# %% [markdown]
# # 4) Qual o projeto recebeu o maior investimento?
# SELECT projetos.nome, projetos.proponente, projetos.valor_aprovado, projetos.valor_captado
# FROM projetos
# WHERE projetos.valor_captado in (SELECT MAX(projetos.valor_captado) FROM projetos)
#
# Mediante a amostra fornecida e a consulta feita no Banco de dados todos os resultados de valores capitados é igual a 0 assim nenhum projeto recebeu investimnto.

# %% [markdown]
# # 5) Qual empresa investiu mais na Lei Rouanet ao longo do tempo?
# SELECT incentivadores.nome, COUNT(incentivadores.nome), SUM(incentivadores.total_doado)
# FROM incentivadores
# GROUP BY incentivadores.nome
#
# EMPRESA QUE MAIS INVESTIU NA LEI ROUANET
#
# nome: Banco do Brasil S.A
# valor: 496,940,360.91

# %% [markdown]
# # 6) Qual foi a empresa mais beneficiada ao longo do tempo?
# SELECT projetos.proponente, COUNT(projetos.proponente), SUM(projetos.valor_aprovado)
# FROM projetos
# GROUP BY projetos.proponente
#
#
# Mediante a amostra fornecida e a consulta feita no Banco de dados todos os resultados de valores aprovados foi igual a 0 assim nenhuma das empresas foi beneficiada

# %% [markdown]
# # * 7) Há algum solicitante que sempre ganha?
#
# Partindo dos resultados das questões anteriores, Mediante a amostra fornecida e a consulta feita no Banco de dados nenhuma das empresas foi beneficiada

# %% [markdown]
# # * 8) Consegue associar algum CNPJ a algum artista conhecido?
# SELECT projetos.cgccpf, projetos.proponente
# FROM projetos
#
# Após uma analise pessoal mediante a amostra fornecida e a consulta feita no Banco de dados, não foi encontrado nenhum CNPJ associado a algum artista conhecido.

# %% [markdown]
# # * 9) Apresente suas conclusões e hipóteses para o futuro baseado nos fatos encontrados.
#
# É muito complicado apresentar uma conclusão para projetos futuros, visto que a amostra de dados fornecida é muito inconsistente, seria necessário uma amostra de dados maior para se tornar possivél uma analise concreta de possivéis acontecimentos.
