# %% [markdown]
# <h3>Insira seu trabalho, já no formato jupyter, no github comunitário, elencando as perguntas que você selecionou para responder. Em seguida, poste o link:</h3>

# %% [markdown]
# <b>Sobre a base de dados usada:</b>
#
# Steam is the world's most popular PC Gaming hub. With a massive collection that includes everything from AAA blockbusters to small indie titles, great discovery tools can be super valuable for Steam. How can we make them better?
#
# This dataset is a list of user behaviors, with columns: user-id, game-title, behavior-name, value. The behaviors included are 'purchase' and 'play'. The value indicates the degree to which the behavior was performed - in the case of 'purchase' the value is always 1, and in the case of 'play' the value represents the number of hours the user has played the game.
#
# <b>Importante:</b> Não usaremos a coluna 'Other'.

# %%
#importando libs
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Carregando os dados
dados = pd.read_csv("./Dados/steam-200k.csv", header=None, index_col=None,
                 names=['UserID', 'Game', 'Action', 'Hours', 'Other'])
dados.head(15)
# Out:
#        UserID                        Game    Action  Hours  Other
# 0   151603712  The Elder Scrolls V Skyrim  purchase    1.0      0
# 1   151603712  The Elder Scrolls V Skyrim      play  273.0      0
# 2   151603712                   Fallout 4  purchase    1.0      0
# 3   151603712                   Fallout 4      play   87.0      0
# 4   151603712                       Spore  purchase    1.0      0
# 5   151603712                       Spore      play   14.9      0
# 6   151603712           Fallout New Vegas  purchase    1.0      0
# 7   151603712           Fallout New Vegas      play   12.1      0
# 8   151603712               Left 4 Dead 2  purchase    1.0      0
# 9   151603712               Left 4 Dead 2      play    8.9      0
# 10  151603712                    HuniePop  purchase    1.0      0
# 11  151603712                    HuniePop      play    8.5      0
# 12  151603712               Path of Exile  purchase    1.0      0
# 13  151603712               Path of Exile      play    8.1      0
# 14  151603712                 Poly Bridge  purchase    1.0      0

# %% [markdown]
# <b>Perguntas:</b>
#
# 1. Qual o jogo mais jogado?
# 2. Qual jogo teve o maior número de compras?
# 3. As horas jogadas e a quantidade de compras são proporcionais? (quanto mais horas jogadas, maior o número de compras?)
# 4. Quantos jogos, em média, cada jogador possui?
# 5. Quantos jogadores gastam mais de 60% do tempo jogando um único jogo?
# 6. Qual a média de compras realizadas pelos jogadores?
# 7. Os 5 jogos mais jogados pertencem a mesma categoria de jogo?
