# %% [markdown]
# # Crawler site globo.com

# %%
import requests
from bs4 import BeautifulSoup

# %%
page = requests.get("http://www.globo.com/")

soup = BeautifulSoup(page.content, 'html.parser')
titulo_link = soup.findAll('a', class_='hui-premium__link')
titulo_link2 = soup.findAll('a', class_='hui-hover-effect__trigger')

# %%
for tl in titulo_link:
    print('Título da Notícia')
    print(tl['title'])
    print('Link da Notícia:')
    print(tl['href'], '\n')
    
for tl2 in titulo_link2:
    print('Título da Notícia')
    print(tl2['title'])
    print('Link da Notícia:')
    print(tl2['href'], '\n')
# Out:
# Título da Notícia
# Deputados contra e a favor da intervenção no RJ discursam
# Link da Notícia:
# https://g1.globo.com/rj/rio-de-janeiro/ao-vivo/camara-vota-decreto-de-intervencao-federal-no-rio-de-janeiro.ghtml
#
# Título da Notícia
# Governo desiste de votar reforma e cita projetos (reprodução)
# Link da Notícia:
# https://g1.globo.com/politica/noticia/governo-desiste-da-votacao-da-previdencia-e-anuncia-nova-pauta-prioritaria-no-congresso.ghtml
#
# Título da Notícia
# Crivella diz que não sabia sobre cirurgia da mãe (Reprodução)
# Link da Notícia:
# https://g1.globo.com/rj/rio-de-janeiro/noticia/crivella-justifica-atendimento-da-mae-em-hospital-publico-poderia-perder-o-braco.ghtml
#
# Título da Notícia
# Preso, Maluf é afastado do mandato (Adriano Machado/Reuters)
# Link da Notícia:
# https://g1.globo.com/politica/noticia/rodrigo-maia-afasta-paulo-maluf-do-mandato-de-deputado-federal.ghtml
#
# Título da Notícia
# Dois suspeitos de matar PM no RJ são inocentados
# Link da Notícia:
# ...
