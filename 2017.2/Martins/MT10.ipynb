# %% [markdown]
# # Pesquisa BBC - Limpeza de Dados

# %% [markdown]
# ## Procedimentos Efetuados
#
# ### Utilizando a ferramenta de filtro do excel:
# #### Foram identificados os valores que possuíam caracteres no lugar onda deveriam haver números (incluindo símbolos, como porcentagem (%) e 'e' comercial (&), bem como espaços vazios;
# #### Nos valores que possuim símbolos ou caracteres especiais, os mesmos foram apagados. Qualquer inconsistência que fosse encontrado em 2 ou mais informações da mesma linha (incluindo espaços vazios) tiveram sua célula apagada.
# #### Símbolos de percentagem removidos: 219
# #### Quantidade de linhas faltando mais de 2 informações apagadas: 50
# #### Linhas com inconsistências apagadas: 1856, 2722, 2812, 5395, 6703, 8615, 8839, 9108, 9155.

# %%
import pandas as pd

dataframe_excel = pd.read_excel('BBC Results - Lesson 1(MT10).xlsx', sheetname=0, header=0)

# %%
dataframe_excel.head()
# Out:
#             Timestamp  How many hours did you sleep last night?  \
# 0 2012-12-11 18:16:31                                       7.0
# 1 2012-12-13 14:31:16                                       6.5
# 2 2012-12-13 14:31:30                                       7.0
# 3 2012-12-13 14:32:01                                       5.0
# 4 2012-12-13 14:34:07                                       8.5
#
#    Recognition Score  Temporal Memory Score
# 0               91.0                   86.0
# 1               95.0                   78.0
# 2               95.0                   56.0
# 3               91.0                   81.0
# 4              100.0                   75.0

# %%
print(dataframe_excel)
# Out:
#                Timestamp  How many hours did you sleep last night?  \
# 0    2012-12-11 18:16:31                                       7.0
# 1    2012-12-13 14:31:16                                       6.5
# 2    2012-12-13 14:31:30                                       7.0
# 3    2012-12-13 14:32:01                                       5.0
# 4    2012-12-13 14:34:07                                       8.5
# 5    2012-12-13 14:34:16                                       7.0
# 6    2012-12-13 14:35:50                                       6.5
# 7    2012-12-13 14:36:36                                       8.5
# 8    2012-12-13 14:44:30                                       6.5
# 9    2012-12-13 14:44:57                                       7.0
# 10   2012-12-13 14:48:38                                       8.0
# 11   2012-12-13 14:54:44                                       7.5
# 12   2012-12-13 14:58:49                                       8.0
# ...
