# %%
import pandas as pd

df = pd.read_csv('BBC_Results.csv')
df
# Out:
#                 Timestamp  How many hours did you sleep last night?  \
# 0     12/11/2012 18:16:31                                       7.0
# 1     12/13/2012 14:31:16                                       6.5
# 2     12/13/2012 14:31:30                                       7.0
# 3     12/13/2012 14:32:01                                       5.0
# 4     12/13/2012 14:34:07                                       8.5
# 5     12/13/2012 14:34:16                                       7.0
# 6     12/13/2012 14:35:50                                       6.5
# 7     12/13/2012 14:36:36                                       8.5
# 8     12/13/2012 14:44:30                                       6.5
# 9     12/13/2012 14:44:57                                       7.0
# 10    12/13/2012 14:48:38                                       8.0
# 11    12/13/2012 14:54:44                                       7.5
# 12    12/13/2012 14:58:49                                       8.0
# ...

# %%
df.dtypes
# Out:
# Timestamp                                    object
# How many hours did you sleep last night?    float64
# Recognition Score                            object
# Temporal Memory Score                        object
# dtype: object

# %%
df['How many hours did you sleep last night?'].mean()
# Out:
# 6.6963076250819311

# %%
df[df['How many hours did you sleep last night?'].isnull()]
# Out:
#                 Timestamp  How many hours did you sleep last night?  \
# 5742  12/16/2013 12:54:45                                       NaN
# 7692    7/21/2014 8:03:39                                       NaN
#
#      Recognition Score Temporal Memory Score
# 5742               NaN                   NaN
# 7692                75                    75

# %%
df['How many hours did you sleep last night?'].fillna(df['How many hours did you sleep last night?'].mean(), inplace=True)

# %%
df[df['How many hours did you sleep last night?'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Timestamp, How many hours did you sleep last night?, Recognition Score, Temporal Memory Score]
# Index: []

# %%
df[df['Recognition Score'].isnull()]
# Out:
#                 Timestamp  How many hours did you sleep last night?  \
# 924     2/14/2013 6:04:33                                       6.0
# 925     2/14/2013 6:04:49                                       6.0
# 944    2/14/2013 14:45:45                                       8.0
# 950    2/14/2013 16:31:11                                       0.0
# 1003    2/16/2013 9:51:03                                       8.0
# 1004    2/16/2013 9:51:42                                       0.0
# 1005    2/16/2013 9:52:00                                       8.0
# 1122    2/20/2013 7:59:02                                       9.0
# 1194   2/21/2013 15:24:09                                       0.0
# 1328   2/25/2013 10:05:55                                       6.0
# 1380    2/27/2013 4:59:12                                       8.0
# 1385    2/27/2013 8:41:01                                       7.0
# 1387    2/27/2013 8:46:41                                       6.5
# ...

# %%
df[df['Recognition Score'].isnull()]
